# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
#from api_keys import api_key
api_key = "497f406e28543f246828d7fbed52b732"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../Resources/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

print(api_key)
# Out:
# 497f406e28543f246828d7fbed52b732

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 656

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{url}appid=497f406e28543f246828d7fbed52b732&q={city}"

# %%
response = requests.get(query_url).json()

print(response)
# Out:
# {'coord': {'lon': -46, 'lat': -20.63}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 290.73, 'pressure': 1020.1, 'humidity': 67, 'temp_min': 290.73, 'temp_max': 290.73, 'sea_level': 1020.1, 'grnd_level': 911.01}, 'wind': {'speed': 2.05, 'deg': 55.308}, 'clouds': {'all': 0}, 'dt': 1561692146, 'sys': {'message': 0.0071, 'country': 'BR', 'sunrise': 1561714829, 'sunset': 1561754022}, 'timezone': -10800, 'id': 3453439, 'name': 'Ponta do Sol', 'cod': 200}

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    try: 
        response = requests.get(query_url).json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        
        # Increase counter by one as it loops
        record = record + 1
        
    #add in an except
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Ponta do Sol
# Processing Record 2 | Ponta do Sol
# Processing Record 3 | Ponta do Sol
# Processing Record 4 | Ponta do Sol
# Processing Record 5 | Ponta do Sol
# Processing Record 6 | Ponta do Sol
# Processing Record 7 | Ponta do Sol
# Processing Record 8 | Ponta do Sol
# Processing Record 9 | Ponta do Sol
# Processing Record 10 | Ponta do Sol
# Processing Record 11 | Ponta do Sol
# Processing Record 12 | Ponta do Sol
# Processing Record 13 | Ponta do Sol
# Processing Record 14 | Ponta do Sol
# Processing Record 15 | Ponta do Sol
# Processing Record 16 | Ponta do Sol
# Processing Record 17 | Ponta do Sol
# Processing Record 18 | Ponta do Sol
# Processing Record 19 | Ponta do Sol
# Processing Record 20 | Ponta do Sol
# Processing Record 21 | Ponta do Sol
# Processing Record 22 | Ponta do Sol
# Processing Record 23 | Ponta do Sol
# Processing Record 24 | Ponta do Sol
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dict
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a df from a dict
weather_data = pd.DataFrame(weatherpy_dict)

# show count of weather data values 
weather_data.count()
# Out:
# City          656
# Cloudiness    656
# Country       656
# Date          656
# Humidity      656
# Lat           656
# Lng           656
# Max Temp      656
# Wind Speed    656
# dtype: int64

# %%
# Save df to CSV
weather_data.to_csv("../Resources/weather_data.csv")

weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat  Lng  \
# 0  Ponta do Sol           0      BR  1561692146        67 -20.63  -46
# 1  Ponta do Sol           0      BR  1561692146        67 -20.63  -46
# 2  Ponta do Sol           0      BR  1561692146        67 -20.63  -46
# 3  Ponta do Sol           0      BR  1561692146        67 -20.63  -46
# 4  Ponta do Sol           0      BR  1561692146        67 -20.63  -46
#
#    Max Temp  Wind Speed
# 0    290.73        2.05
# 1    290.73        2.05
# 2    290.73        2.05
# 3    290.73        2.05
# 4    290.73        2.05

# %%
#

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# properties
plt.title("City Latitude vs. Max Temperature 6/27/2019")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the chart
plt.savefig("../Resources/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# properties
plt.title("City Latitude vs. Humidity 6/27/2019")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the chart
plt.savefig("../Resources/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# properties
plt.title("City Latitude vs. Cloudiness 6/27/2019")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save chart
plt.savefig("../Resources/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# properties
plt.title("City Latitude vs. Wind Speed 6/27/2019")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save chart
plt.savefig("../Resources/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
